# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table
from astropy import units as u
plt.ion()
import os

# %%
a = 50.0 * u.meter
b = [23, 45, 88] * u.meter
print(a)
print(b)
# Out:
# 50.0 m
# [23. 45. 88.] m

# %%
np.mean(b)
# Out:
# <Quantity 52. m>

# %%
15 * u.meter / (3 * u.second)
# Out:
# <Quantity 5. m / s>

# %%
x = 62 * u.parsec
print(x)
# Out:
# 62.0 pc

# %%
y = 45 * u.parsec

# %%
x/y
# Out:
# <Quantity 1.37777778>

# %%
z = x.value
print(z)
# Out:
# 62.0

# %%
z = x.value/y.value

# %%
z
# Out:
# 1.3777777777777778

# %%
np.around(z, decimals=2)
# Out:
# 1.38

# %%
type(x)
# Out:
# astropy.units.quantity.Quantity

# %%
c = [4, 7, 10] * u.second

# %%
plt.figure(figsize=[10,7])
plt.plot(c, b, ls="", color="r", marker='o', label='displacement')
plt.xlabel("t[s]", fontsize=14)
plt.ylabel("x[m]", fontsize=14)
plt.title("x vs t", fontsize=14)
plt.legend()

l1 = np.linspace(0, 100, 10)
l2 = np.linspace(0, 100, 10)
plt.plot(l1,l2,color='gray',ls="--")
